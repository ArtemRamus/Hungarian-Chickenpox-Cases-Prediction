# %% [markdown]
# # Project: Hungarian Chickenpox Cases Forecasting
#
# Abstract: A spatio-temporal dataset of weekly chickenpox cases from Hungary. The dataset consists of a county-level adjacency matrix and time series of the county-level reported cases between 2005 and 2015.

# %% [markdown]
# # About the datases:
#
# link to hte dataset at UCI: https://archive.ics.uci.edu/ml/datasets/Hungarian+Chickenpox+Cases
#
# Data Set Characteristics: Time-Series
#
# Number of Instances: 521
#
# Area: Life
#
# Attribute Characteristics: Real
#
# Number of Attributes: 20
#
# Date Donated 2021-02-17
#
# Associated Tasks: Regression
#
# Missing Values? N/A
#
# Number of Web Hits: 24976
#
# ## Source:
#
# Benedek Rozemberczki, The University of Edinburgh, benedek.rozemberczki '@' gmail.com
#
# ## Data Set Information:
#
# A spatio-temporal dataset of weekly chickenpox (childhood disease) cases from Hungary. The dataset consists of a county-level adjacency matrix and time series of the county-level reported cases between 2005 and 2015. There are 2 specific related tasks: County level case count prediction and nation level case count prediction.
#
# ## Attribute Information:
#
# Attributes are weekly counts of chickenpox cases in Hungarian counties.
#
#
# ## Relevant Papers:
#
# Chickenpox Cases in Hungary: a Benchmark Dataset for Spatiotemporal Signal Processing with Graph Neural Networks
# Benedek Rozemberczki, Paul Scherer, Oliver Kiss, Rik Sarkar, Tamas Ferenci
#
#
#
# ## Citation Request:
#
# @misc{rozemberczki2021chickenpox,
# title={Chickenpox Cases in Hungary: a Benchmark Dataset for Spatiotemporal Signal Processing with Graph Neural Networks},
# author={Benedek Rozemberczki and Paul Scherer and Oliver Kiss and Rik Sarkar and Tamas Ferenci},
# year={2021},
# eprint={2102.08100},
# archivePrefix={arXiv},
# primaryClass={cs.SI}
# }

# %% [markdown]
# ## Discussion: SARIMA and LSTM RNN has demonstrared similar performance

# %% [markdown]
# # County-wide cases prediction

# %% [markdown]
# ## STEP 1: Learning the dataset and feature engineering

# %%
# importing libraries
# for working with arrays and dataframes
import numpy as np
import pandas as pd

# for plotting
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
import scipy.stats as stats # for Q-Q plots

# %%
df = pd.read_csv("hungary_chickenpox.csv")

# %%
# df.head

# %%
# setting "Date" to be the index
df.set_index('Date',inplace=True)
df.index.freq = 'W'
df.index = pd.to_datetime(df.index, format='%d/%m/%Y')

# %%
# showing the dateset
# df.head()

# %%
# showing an information about the dataset
# df.info()

# %%
# showing statistical information about the dataset
# df.describe()

# %%
# summing up all the columns
df['Total_Cases'] = df.iloc[:, 1:].sum(axis = 1, skipna = True)

# %%
# showing the dateset
# df.head()

# %% [markdown]
# ### Plotting the series

# %%
title = 'Total chickenpox cases in Hungary'
ylabel = 'Chickenpox cases in Hungary'
xlabel = 'Date'

ax = df['Total_Cases'].plot(figsize=(12,6),title=title)
ax.autoscale(axis='x',tight=True)
ax.set(xlabel=xlabel, ylabel=ylabel);

# %% [markdown]
# Discussion: downward trend and annual oscillations have been observed.

# %% [markdown]
# ### Treating outliers

# %% [markdown]
# Resampling the data with monthly frequency

# %%
df = df.resample('M').mean()

# %%
title = 'Total chickenpox cases in Hungary'
ylabel = 'Chickenpox cases in Hungary'
xlabel = 'Date'

ax = df['Total_Cases'].plot(figsize=(12,6),title=title)
ax.autoscale(axis='x',tight=True)
ax.set(xlabel=xlabel, ylabel=ylabel);

# %% [markdown]
# ## STEP 2: Analyzing country-wide the time series and predicting with SARIMA

# %% [markdown]
# ### SARIMA optimized with autoARIMA

# %%
# Load specific forecasting tools
from statsmodels.tsa.statespace.sarimax import SARIMAX

from statsmodels.graphics.tsaplots import plot_acf,plot_pacf # for determining (p,q) orders
from statsmodels.tsa.seasonal import seasonal_decompose      # for ETS Plots
from pmdarima import auto_arima                              # for determining ARIMA orders

# Ignore harmless warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Running ETS decomposition

# %%
# decomposing the series to trend, seasonal and residual and then plotting them
result = seasonal_decompose(df['Total_Cases'], model='add')
result.plot();

# %% [markdown]
# ### Runing pmdarima.auto_arima to obtain recommended orders

# %% [markdown]
# Discussion: the decomposition shows a prominent seasonal component and an unclear trend.

# %%
# for SARIMA orders setting seasonal=True and pass in an m value
auto_arima(df['Total_Cases'],seasonal=True,m=12).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                                    y   No. Observations:                  120
# Model:             SARIMAX(1, 0, 0)x(1, 0, [1], 12)   Log Likelihood                -772.524
# Date:                              Tue, 28 Sep 2021   AIC                           1555.049
# Time:                                      08:24:59   BIC                           1568.986
# Sample:                                           0   HQIC                          1560.709
#                                               - 120
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      5.2172      5.183      1.007      0.314      -4.941      15.375
# ar.L1          0.6668      0.074      9.038      0.000       0.522       0.811
# ar.S.L12       0.9776      0.017     56.350      0.000       0.944       1.012
# ma.S.L12      -0.6130      0.143     -4.277      0.000      -0.894      -0.332
# sigma2      1.893e+04   1435.883     13.185      0.000    1.61e+04    2.17e+04
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.65   Jarque-Bera (JB):               109.50
# Prob(Q):                              0.20   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.51   Skew:                            -0.97
# Prob(H) (two-sided):                  0.03   Kurtosis:                         7.26
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# This provides an ARIMA Order of (1,0,0) combined with a seasonal order of (1,0,1,12) Now let's train & test the SARIMA(1,0,0)(1,0,1,12) model, evaluate it, then produce a forecast of future values.

# %% [markdown]
# ### Splitting the data into train/test sets

# %%
len(df)
# Out:
# 120

# %%
# setting one year for testing
train = df.iloc[:109]
test = df.iloc[109:]

# %%
# fitting SARIMA(1,0,0)(1,0,1,12) model
model = SARIMAX(train['Total_Cases'],order=(1,0,0),seasonal_order=(1,0,1,12))
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                          Total_Cases   No. Observations:                  109
# Model:             SARIMAX(1, 0, 0)x(1, 0, [1], 12)   Log Likelihood                -701.673
# Date:                              Tue, 28 Sep 2021   AIC                           1411.347
# Time:                                      08:25:00   BIC                           1422.112
# Sample:                                  01-31-2005   HQIC                          1415.713
#                                        - 01-31-2014
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.7908      0.043     18.262      0.000       0.706       0.876
# ar.S.L12       0.9925      0.010     95.191      0.000       0.972       1.013
# ma.S.L12      -0.7415      0.176     -4.220      0.000      -1.086      -0.397
# sigma2       1.75e+04   1493.187     11.722      0.000    1.46e+04    2.04e+04
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.61   Jarque-Bera (JB):               207.43
# Prob(Q):                              0.44   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.63   Skew:                            -1.35
# Prob(H) (two-sided):                  0.17   Kurtosis:                         9.19
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
# obtaining predicted values
start=len(train)
end=len(train)+len(test)-1
predictions = results.predict(start=start, end=end, dynamic=False, typ='levels').rename('SARIMA(1,0,0)(1,0,1,12) Predictions')

# %%
# plotting predictions against known values
title = 'Total chickenpox cases in Hungary'
ylabel = 'Chickenpox cases in Hungary'
xlabel = 'Date'

ax = test['Total_Cases'].plot(legend=True,figsize=(12,6),title=title)
predictions.plot(legend=True)
ax.autoscale(axis='x',tight=True)
ax.set(xlabel=xlabel, ylabel=ylabel);

# %% [markdown]
# ### Evaluating the model

# %%
from statsmodels.tools.eval_measures import rmse

error = rmse(test['Total_Cases'], predictions)
print(f'SARIMA(1,0,0)(1,0,1,12) RMSE Error: {error:11.10}')
# Out:
# SARIMA(1,0,0)(1,0,1,12) RMSE Error: 139.3851334

# %% [markdown]
# Discussion: the high prediction errors might be explained by the fact that the predicted year differs from two previous by two spikes, downward-facing and upward-facing, in April and May 2014.

# %% [markdown]
# ### Retraining the model on the full data, and forecasting the future

# %%
model = SARIMAX(df['Total_Cases'],order=(1,0,0),seasonal_order=(1,0,1,12))
results = model.fit()
fcast = results.predict(len(df),len(df)+11,typ='levels').rename('SARIMA(1,0,0)(1,0,1,12) Forecast')

# %%
# plotting predictions against known values
title = 'Total chickenpox cases in Hungary'
ylabel = 'Chickenpox cases in Hungary'
xlabel = 'Date'

ax = df['Total_Cases'].plot(legend=True,figsize=(12,6),title=title)
fcast.plot(legend=True)
ax.autoscale(axis='x',tight=True)
ax.set(xlabel=xlabel, ylabel=ylabel);

# %% [markdown]
# #### Summary: SARIMA(1,0,0)(1,0,1,12) has reasonably repeated the time series pattern after interpolating from weekly to monthly sampling.

# %% [markdown]
# ## STEP 3: Predicting country-wise cases with LSTM RNN

# %% [markdown]
# # First, predicting the test set

# %% [markdown]
# ### Scale the data

# %%
# importing MinMax scaler
from sklearn.preprocessing import MinMaxScaler

# %%
# defining a scaler
scaler = MinMaxScaler()

# %%
# train

# %%
train.columns
# Out:
# Index(['BUDAPEST', 'BARANYA', 'BACS', 'BEKES', 'BORSOD', 'CSONGRAD', 'FEJER',
#        'GYOR', 'HAJDU', 'HEVES', 'JASZ', 'KOMAROM', 'NOGRAD', 'PEST', 'SOMOGY',
#        'SZABOLCS', 'TOLNA', 'VAS', 'VESZPREM', 'ZALA', 'Total_Cases'],
#       dtype='object')

# %%
# creating train_total and test_total datasets only with "Total_Cases" column
columns_to_drop = ['BUDAPEST', 'BARANYA', 'BACS', 'BEKES', 'BORSOD', 'CSONGRAD', 'FEJER',
       'GYOR', 'HAJDU', 'HEVES', 'JASZ', 'KOMAROM', 'NOGRAD', 'PEST', 'SOMOGY',
       'SZABOLCS', 'TOLNA', 'VAS', 'VESZPREM', 'ZALA']
train_total = train.drop(columns_to_drop, axis = 1)
test_total = test.drop(columns_to_drop, axis = 1)
# train_total
# test_total

# %%
# fitting the scaler
scaler.fit(train_total)
# Out:
# MinMaxScaler()

# %%
# scaling the series
scaled_train = scaler.transform(train_total)
scaled_test = scaler.transform(test_total)

# %% [markdown]
# ### Time series senerator

# %%
# importing a generator
from keras.preprocessing.sequence import TimeseriesGenerator

# %%
# defining time series generator with 12 steps forwqrd generating
n_input = 12
generator = TimeseriesGenerator(scaled_train, scaled_train, length=n_input, batch_size=1)

# %%
# calculating first batch
# X,y = generator[0]

# %%
# printing the first batch and first month prediction
# print(f'Given the Array: \n{X.flatten()}')
# print(f'Predict this y: \n {y}')

# %% [markdown]
# ### Building a model

# %%
# importing the libraries
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM

# %%
# defining the model
n_features = 1   # for single time series
model = Sequential()
model.add(LSTM(576, activation='relu', input_shape=(n_input, n_features)))
# model.add(Dense(144, activation='relu'))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# %%
# model.summary()

# %%
# fitting the model
model.fit_generator(generator,epochs=50)
# Out:
# WARNING:tensorflow:From <ipython-input-38-3b07ac1f51e0>:2: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/50
# 97/97 [==============================] - 3s 31ms/step - loss: 0.0621
# Epoch 2/50
# 97/97 [==============================] - 3s 31ms/step - loss: 0.0431
# Epoch 3/50
# 97/97 [==============================] - 3s 30ms/step - loss: 0.0235
# Epoch 4/50
# 97/97 [==============================] - 3s 31ms/step - loss: 0.0194
# Epoch 5/50
# 97/97 [==============================] - 3s 32ms/step - loss: 0.0142
# Epoch 6/50
# 97/97 [==============================] - 3s 33ms/step - loss: 0.0167
# Epoch 7/50
# 97/97 [==============================] - 3s 33ms/step - loss: 0.0157
# Epoch 8/50
# 97/97 [==============================] - 3s 32ms/step - loss: 0.0142
# Epoch 9/50
# 97/97 [==============================] - 3s 32ms/step - loss: 0.0156
# Epoch 10/50
# 97/97 [==============================] - 3s 33ms/step - loss: 0.0129
# Epoch 11/50
# 97/97 [==============================] - 3s 31ms/step - loss: 0.0129
# Epoch 12/50
# 97/97 [==============================] - 3s 32ms/step - loss: 0.0125
# Epoch 13/50
# 97/97 [==============================] - 3s 32ms/step - loss: 0.0112
# Epoch 14/50
# 97/97 [==============================] - 3s 32ms/step - loss: 0.0107: 0s -
# Epoch 15/50
# 97/97 [==============================] - 3s 32ms/step - loss: 0.0115
# Epoch 16/50
# 97/97 [==============================] - 3s 32ms/step - loss: 0.0096
# Epoch 17/50
# 97/97 [==============================] - 3s 32ms/step - loss: 0.0112
# Epoch 18/50
# 97/97 [==============================] - 3s 32ms/step - loss: 0.0097
# Epoch 19/50
# 97/97 [==============================] - 3s 32ms/step - loss: 0.0103
# Epoch 20/50
# 97/97 [==============================] - 3s 32ms/step - loss: 0.0086
# Epoch 21/50
# 97/97 [==============================] - 3s 32ms/step - loss: 0.0089
# Epoch 22/50
# 97/97 [==============================] - 3s 33ms/step - loss: 0.0079
# Epoch 23/50
# 97/97 [==============================] - 3s 32ms/step - loss: 0.0086
# Epoch 24/50
# 97/97 [==============================] - 3s 32ms/step - loss: 0.0094
# Epoch 25/50
# 97/97 [==============================] - 3s 32ms/step - loss: 0.0078
# Epoch 26/50
# 97/97 [==============================] - 3s 33ms/step - loss: 0.0075
# Epoch 27/50
# 97/97 [==============================] - 3s 32ms/step - loss: 0.0080
# Epoch 28/50
# 97/97 [==============================] - 3s 32ms/step - loss: 0.0082
# Epoch 29/50
# 97/97 [==============================] - 3s 33ms/step - loss: 0.0074
# Epoch 30/50
# 97/97 [==============================] - 3s 32ms/step - loss: 0.0073
# Epoch 31/50
# 97/97 [==============================] - 3s 32ms/step - loss: 0.0077
# Epoch 32/50
# 97/97 [==============================] - 3s 32ms/step - loss: 0.0075
# Epoch 33/50
# 97/97 [==============================] - 3s 32ms/step - loss: 0.0066
# Epoch 34/50
# 97/97 [==============================] - 3s 32ms/step - loss: 0.0078
# Epoch 35/50
# 97/97 [==============================] - 3s 32ms/step - loss: 0.0071
# Epoch 36/50
# 97/97 [==============================] - 3s 32ms/step - loss: 0.0090
# Epoch 37/50
# 97/97 [==============================] - 3s 33ms/step - loss: 0.0080
# Epoch 38/50
# 97/97 [==============================] - 3s 32ms/step - loss: 0.0069
# Epoch 39/50
# 97/97 [==============================] - 3s 31ms/step - loss: 0.0066
# Epoch 40/50
# 97/97 [==============================] - 3s 31ms/step - loss: 0.0076
# Epoch 41/50
# 97/97 [==============================] - 3s 32ms/step - loss: 0.0071
# Epoch 42/50
# 97/97 [==============================] - 3s 32ms/step - loss: 0.0073
# Epoch 43/50
# 97/97 [==============================] - 3s 33ms/step - loss: 0.0062
# Epoch 44/50
# 97/97 [==============================] - 3s 33ms/step - loss: 0.0070
# Epoch 45/50
# 97/97 [==============================] - 3s 33ms/step - loss: 0.0067
# Epoch 46/50
# 97/97 [==============================] - 3s 35ms/step - loss: 0.0074
# Epoch 47/50
# 97/97 [==============================] - 3s 34ms/step - loss: 0.0067
# Epoch 48/50
# 97/97 [==============================] - 3s 33ms/step - loss: 0.0073
# Epoch 49/50
# 97/97 [==============================] - 3s 35ms/step - loss: 0.0064
# Epoch 50/50
# 97/97 [==============================] - 3s 35ms/step - loss: 0.0065

# %%
#showing the convergence log columns
model.history.history.keys()
# Out:
# dict_keys(['loss'])

# %%
# printing the convergence log
loss_per_epoch = model.history.history['loss']
plt.plot(range(len(loss_per_epoch)),loss_per_epoch);

# %% [markdown]
# ### Evaluating the test data

# %%
# first batch
first_eval_batch = scaled_train[-12:]

# %%
# first_eval_batch

# %%
# reshaping the first batch
first_eval_batch = first_eval_batch.reshape((1, n_input, n_features))

# %%
# first_eval_batch

# %%
# predicting first vaue of the test series
model.predict(first_eval_batch)
# Out:
# array([[0.57488585]], dtype=float32)

# %%
scaled_test[0]
# Out:
# array([0.37475042])

# %% [markdown]
# Predicting into the future for the entire test range

# %%
test_predictions = []

first_eval_batch = scaled_train[-n_input:]
current_batch = first_eval_batch.reshape((1, n_input, n_features))

# %%
current_batch.shape
# Out:
# (1, 12, 1)

# %%
current_batch
# Out:
# array([[[0.55552143],
#         [0.57948088],
#         [0.52861312],
#         [0.53616956],
#         [0.41560436],
#         [0.20165873],
#         [0.017816  ],
#         [0.00310244],
#         [0.10766395],
#         [0.21701736],
#         [0.20165873],
#         [0.42313009]]])

# %%
np.append(current_batch[:,1:,:],[[[99]]],axis=1)
# Out:
# array([[[5.79480879e-01],
#         [5.28613116e-01],
#         [5.36169559e-01],
#         [4.15604362e-01],
#         [2.01658731e-01],
#         [1.78160037e-02],
#         [3.10244202e-03],
#         [1.07663953e-01],
#         [2.17017355e-01],
#         [2.01658731e-01],
#         [4.23130088e-01],
#         [9.90000000e+01]]])

# %%
test_predictions = []

first_eval_batch = scaled_train[-n_input:]
current_batch = first_eval_batch.reshape((1, n_input, n_features))

for i in range(len(test)):
    
    # getting a prediction 1 time stamp ahead ([0] is for taking one number instead of [array])
    current_pred = model.predict(current_batch)[0]
    
    # storing the prediction
    test_predictions.append(current_pred) 
    
    # updating batch by including prediction and dropping a first value
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1)

# %%
# test_predictions

# %%
# scaled_test

# %% [markdown]
# ### Making inverse transformations and comparing

# %%
# inverse transformation
true_predictions = scaler.inverse_transform(test_predictions)

# %%
# true_predictions

# %%
# test_total

# %%
# adding "Predictions" column to test_total
test_total['LSTM Predictions'] = true_predictions

# %%
# test_total

# %%
# plotting y & y_hat
test_total.plot(figsize=(12,8));

# %% [markdown]
# ### Evaluating the model

# %%
from statsmodels.tools.eval_measures import rmse

error = rmse(test_total['Total_Cases'], test_total['LSTM Predictions'])
print(f'SARIMA(1,0,0)(1,0,1,12) RMSE Error: {error:11.10}')
# Out:
# SARIMA(1,0,0)(1,0,1,12) RMSE Error: 279.0287183

# %% [markdown]
# Discussion: LSTM error is sensible higher than SARIMA error. This might be because of the fact LSTM did not reflect abrupt fluctuations.

# %% [markdown]
# # Second, predicting one year forward

# %%
# creating df_total dataset only with "Total_Cases" column
df_total = df.drop(columns_to_drop, axis = 1)
# df_total

# %%
# fitting the scaler
scaler.fit(df_total)
# Out:
# MinMaxScaler()

# %%
# scaling the series
scaled_df_total = scaler.transform(df_total)

# %% [markdown]
# ### Time series generator

# %%
# defining time series generator with 12 steps forwqrd generating
n_input = 12
generator = TimeseriesGenerator(scaled_df_total, scaled_df_total, length=n_input, batch_size=1)

# %%
# calculating first batch
# X,y = generator[0]

# %%
# printing the first batch and first month prediction
# print(f'Given the Array: \n{X.flatten()}')
# print(f'Predict this y: \n {y}')

# %% [markdown]
# ### Building a model

# %%
# defining the model
n_features = 1   # for single time series
model = Sequential()
model.add(LSTM(576, activation='relu', input_shape=(n_input, n_features)))
# model.add(Dense(144, activation='relu'))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# %%
# model.summary()

# %%
# fitting the model
model.fit_generator(generator,epochs=50)
# Out:
# Epoch 1/50
# 108/108 [==============================] - 4s 33ms/step - loss: 0.0756
# Epoch 2/50
# 108/108 [==============================] - 4s 33ms/step - loss: 0.0310
# Epoch 3/50
# 108/108 [==============================] - 4s 33ms/step - loss: 0.0300
# Epoch 4/50
# 108/108 [==============================] - 3s 32ms/step - loss: 0.0162
# Epoch 5/50
# 108/108 [==============================] - 4s 33ms/step - loss: 0.0128
# Epoch 6/50
# 108/108 [==============================] - 4s 33ms/step - loss: 0.0131
# Epoch 7/50
# 108/108 [==============================] - 3s 31ms/step - loss: 0.0140
# Epoch 8/50
# 108/108 [==============================] - 3s 31ms/step - loss: 0.0104
# Epoch 9/50
# 108/108 [==============================] - 3s 31ms/step - loss: 0.0133
# Epoch 10/50
# 108/108 [==============================] - 3s 31ms/step - loss: 0.0120
# Epoch 11/50
# 108/108 [==============================] - 3s 31ms/step - loss: 0.0101
# Epoch 12/50
# 108/108 [==============================] - 3s 31ms/step - loss: 0.0113
# Epoch 13/50
# 108/108 [==============================] - 3s 31ms/step - loss: 0.0128
# Epoch 14/50
# 108/108 [==============================] - 3s 31ms/step - loss: 0.0114
# Epoch 15/50
# 108/108 [==============================] - 3s 31ms/step - loss: 0.0096
# Epoch 16/50
# 108/108 [==============================] - 3s 31ms/step - loss: 0.0094
# Epoch 17/50
# 108/108 [==============================] - 3s 31ms/step - loss: 0.0107
# Epoch 18/50
# 108/108 [==============================] - 3s 32ms/step - loss: 0.0088
# Epoch 19/50
# 108/108 [==============================] - 3s 31ms/step - loss: 0.0091
# Epoch 20/50
# 108/108 [==============================] - 3s 32ms/step - loss: 0.0106
# Epoch 21/50
# 108/108 [==============================] - 3s 31ms/step - loss: 0.0096
# Epoch 22/50
# 108/108 [==============================] - 3s 31ms/step - loss: 0.0077
# Epoch 23/50
# 108/108 [==============================] - 3s 31ms/step - loss: 0.0091
# Epoch 24/50
# 108/108 [==============================] - 3s 31ms/step - loss: 0.0090
# Epoch 25/50
# 108/108 [==============================] - 3s 31ms/step - loss: 0.0082
# Epoch 26/50
# 108/108 [==============================] - 3s 31ms/step - loss: 0.0087
# Epoch 27/50
# 108/108 [==============================] - 3s 32ms/step - loss: 0.0083
# Epoch 28/50
# 108/108 [==============================] - 3s 32ms/step - loss: 0.0086
# Epoch 29/50
# 108/108 [==============================] - 3s 32ms/step - loss: 0.0093
# Epoch 30/50
# 108/108 [==============================] - 4s 33ms/step - loss: 0.0083
# Epoch 31/50
# 108/108 [==============================] - 3s 32ms/step - loss: 0.0076
# Epoch 32/50
# 108/108 [==============================] - 3s 32ms/step - loss: 0.0080
# Epoch 33/50
# 108/108 [==============================] - 3s 32ms/step - loss: 0.0085
# Epoch 34/50
# 108/108 [==============================] - 3s 32ms/step - loss: 0.0076
# Epoch 35/50
# 108/108 [==============================] - 3s 32ms/step - loss: 0.0081
# Epoch 36/50
# 108/108 [==============================] - 3s 32ms/step - loss: 0.0077
# Epoch 37/50
# 108/108 [==============================] - 3s 32ms/step - loss: 0.0095
# Epoch 38/50
# 108/108 [==============================] - 3s 32ms/step - loss: 0.0075
# Epoch 39/50
# 108/108 [==============================] - 3s 32ms/step - loss: 0.0082
# Epoch 40/50
# 108/108 [==============================] - 3s 32ms/step - loss: 0.0067
# Epoch 41/50
# 108/108 [==============================] - 3s 32ms/step - loss: 0.0089
# Epoch 42/50
# 108/108 [==============================] - 3s 32ms/step - loss: 0.0078
# Epoch 43/50
# 108/108 [==============================] - 4s 32ms/step - loss: 0.0071
# Epoch 44/50
# 108/108 [==============================] - 3s 32ms/step - loss: 0.0086
# Epoch 45/50
# 108/108 [==============================] - 3s 32ms/step - loss: 0.0072
# Epoch 46/50
# 108/108 [==============================] - 3s 32ms/step - loss: 0.0088
# Epoch 47/50
# 108/108 [==============================] - 3s 32ms/step - loss: 0.0079
# Epoch 48/50
# 108/108 [==============================] - 3s 32ms/step - loss: 0.0067
# Epoch 49/50
# 108/108 [==============================] - 3s 32ms/step - loss: 0.0072
# Epoch 50/50
# 108/108 [==============================] - 3s 32ms/step - loss: 0.0079

# %%
#showing the convergence log columns
model.history.history.keys()
# Out:
# dict_keys(['loss'])

# %%
# printing the convergence log
loss_per_epoch = model.history.history['loss']
plt.plot(range(len(loss_per_epoch)),loss_per_epoch);

# %% [markdown]
# ### Saving and loading the model

# %%
model.save('my_rnn_model.h5')

# %%
from keras.models import load_model
new_model = load_model('my_rnn_model.h5')

# %%
# new_model.summary()

# %% [markdown]
# ### Predicting 12 steps forward

# %%
# first batch
first_eval_batch = scaled_df_total[-12:]

# %%
# first_eval_batch

# %%
# reshaping the first batch
first_eval_batch = first_eval_batch.reshape((1, n_input, n_features))

# %%
# first_eval_batch

# %% [markdown]
# Predicting into the future for the entire test range

# %%
test_predictions = []

first_eval_batch = scaled_df_total[-n_input:]
current_batch = first_eval_batch.reshape((1, n_input, n_features))

# %%
# current_batch.shape

# %%
# current_batch

# %%
np.append(current_batch[:,1:,:],[[[99]]],axis=1)
# Out:
# array([[[3.74750422e-01],
#         [4.97773000e-01],
#         [3.16694824e-01],
#         [6.43526340e-01],
#         [3.40132084e-01],
#         [1.77238519e-01],
#         [3.63999386e-02],
#         [6.05129780e-03],
#         [7.66395331e-02],
#         [1.22715405e-01],
#         [2.94670558e-01],
#         [9.90000000e+01]]])

# %%
lstm_predictions = []

first_eval_batch = scaled_df_total[-n_input:]
current_batch = first_eval_batch.reshape((1, n_input, n_features))

for i in range(len(test)):
    
    # getting a prediction 1 time stamp ahead ([0] is for taking one number instead of [array])
    current_pred = model.predict(current_batch)[0]
    
    # storing the prediction
    lstm_predictions.append(current_pred) 
    
    # updating batch by including prediction and dropping a first value
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1)

# %%
# lstm_predictions

# %% [markdown]
# ### Making inverse transformations and plotting the result

# %%
# inverse transformation
lstm_predictions = scaler.inverse_transform(lstm_predictions)

# %%
# lstm_predictions

# %%
# lstm_predictions.shape

# %%
# writting all the forecasts in single data frame
index = fcast.index[:-1]
fcast_2 = pd.DataFrame(data=lstm_predictions,columns=['LSTM Forecast'],index=index)
fcast_2['SARIMA(1,0,0)(1,0,1,12) Forecast'] = fcast

# %%
# fcast_2

# %%
# plotting predictions against known values
title = 'Total chickenpox cases in Hungary'
ylabel = 'Chickenpox cases in Hungary'
xlabel = 'Date'

ax = df['Total_Cases'].plot(legend=True,figsize=(15,8),title=title)
fcast_2['SARIMA(1,0,0)(1,0,1,12) Forecast'].plot(legend=True)
fcast_2['LSTM Forecast'].plot(legend=True)
ax.autoscale(axis='x',tight=True)
ax.set(xlabel=xlabel, ylabel=ylabel);

# %% [markdown]
# ## Discussion: SARIMA and LSTM RNN has demonstrared similar performance

# %% [markdown]
# ## STEP 4: Exploring per-area the time series

# %%
# making a datades of the cases per area
df_areas = df.copy().drop(['Total_Cases'],axis=1)

# %%
# showing an informaiton about the dataframe
df_areas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 120 entries, 2005-01-31 to 2014-12-31
# Freq: M
# Data columns (total 20 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   BUDAPEST  120 non-null    float64
#  1   BARANYA   120 non-null    float64
#  2   BACS      120 non-null    float64
#  3   BEKES     120 non-null    float64
#  4   BORSOD    120 non-null    float64
#  5   CSONGRAD  120 non-null    float64
#  6   FEJER     120 non-null    float64
#  7   GYOR      120 non-null    float64
#  8   HAJDU     120 non-null    float64
#  9   HEVES     120 non-null    float64
#  10  JASZ      120 non-null    float64
#  11  KOMAROM   120 non-null    float64
#  12  NOGRAD    120 non-null    float64
#  13  PEST      120 non-null    float64
#  14  SOMOGY    120 non-null    float64
#  15  SZABOLCS  120 non-null    float64
#  16  TOLNA     120 non-null    float64
#  17  VAS       120 non-null    float64
#  18  VESZPREM  120 non-null    float64
#  19  ZALA      120 non-null    float64
# dtypes: float64(20)
# memory usage: 19.7 KB

# %%
# plotting all the sries on the same scale
title = 'Chickenpox cases in Hungary'
ylabel = 'Chickenpox cases in Hungary'
xlabel = 'Date'

ax = df_areas.plot(figsize=(16,12),title=title)
ax.autoscale(axis='x',tight=True)
ax.set(xlabel=xlabel, ylabel=ylabel);

# %%
# counting cumulative cases and mean for the period
df_sum = df_areas.sum(axis=0)
df_mean = df_areas.mean(axis=0)

df_areas_metadata = pd.DataFrame(df_mean,columns=['Mean'])
df_areas_metadata['Sum'] = df_sum

df_areas_metadata
# Out:
#                 Mean       Sum
# BUDAPEST  101.636250  12196.35
# BARANYA    34.399167   4127.90
# BACS       37.398333   4487.80
# BEKES      29.017083   3482.05
# BORSOD     57.432500   6891.90
# CSONGRAD   31.728333   3807.40
# FEJER      33.555000   4026.60
# GYOR       41.537083   4984.45
# HAJDU      47.220417   5666.45
# HEVES      29.779583   3573.55
# JASZ       41.250000   4950.00
# KOMAROM    25.672083   3080.65
# NOGRAD     21.968750   2636.25
# PEST       86.477083  10377.25
# SOMOGY     28.002500   3360.30
# SZABOLCS   30.074167   3608.90
# TOLNA      20.542500   2465.10
# VAS        22.703333   2724.40
# VESZPREM   41.018750   4922.25
# ZALA       20.000417   2400.05

# %%
# plotting the cases sums per area
fig, ax = plt.subplots()
fig.set_size_inches(16,10)
ax = sns.barplot(x=df_areas_metadata.sort_values('Sum',ascending=False).index,
                 y=df_areas_metadata.sort_values('Sum',ascending=False).Sum,
                 palette='coolwarm')
plt.xticks(rotation=45);

# %%
# plotting the cases means per area
fig, ax = plt.subplots()
fig.set_size_inches(16,10)
ax = sns.barplot(x=df_areas_metadata.sort_values('Mean',ascending=False).index,
                 y=df_areas_metadata.sort_values('Mean',ascending=False).Mean,
                 palette='coolwarm')
plt.xticks(rotation=45);

# %% [markdown]
# #### Discussion: Budapest and Pest areas cases count is prominently higher than others
